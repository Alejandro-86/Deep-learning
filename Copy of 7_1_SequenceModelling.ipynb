# %% [markdown]
# # Part 1: Sequence Modelling

# %% [markdown]
# __Before starting, we recommend you enable GPU acceleration if you're running on Colab.__

# %%
# Execute this code block to install dependencies when running on colab
try:
    import torch
except:
    from os.path import exists
    from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
    platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
    cuda_output = !ldconfig -p|grep cudart.so|sed -e 's/.*\.\([0-9]*\)\.\([0-9]*\)$/cu\1\2/'
    accelerator = cuda_output[0] if exists('/dev/nvidia0') else 'cpu'

    # !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-1.0.0-{platform}-linux_x86_64.whl torchvision

try: 
    import torchbearer
except:
    # !pip install torchbearer
# Out:
# Collecting torchbearer
#   Downloading https://files.pythonhosted.org/packages/5a/62/79c45d98e22e87b44c9b354d1b050526de80ac8a4da777126b7c86c2bb3e/torchbearer-0.3.0.tar.gz (84kB)
#      |████████████████████████████████| 92kB 1.3MB/s
# Requirement already satisfied: torch>=0.4 in /usr/local/lib/python3.6/dist-packages (from torchbearer) (1.1.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.6/dist-packages (from torchbearer) (0.2.2.post3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from torchbearer) (4.28.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torch>=0.4->torchbearer) (1.16.3)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision->torchbearer) (4.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision->torchbearer) (1.12.0)
# Requirement already satisfied: olefile in /usr/local/lib/python3.6/dist-packages (from pillow>=4.1.1->torchvision->torchbearer) (0.46)
# Building wheels for collected packages: torchbearer
#   Building wheel for torchbearer (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/6c/cb/69/466aef9cee879fb8f645bd602e34d45e754fb3dee2cb1a877a
# Successfully built torchbearer
# Installing collected packages: torchbearer
# Successfully installed torchbearer-0.3.0

# %% [markdown]
# ## Markov chains
#
# We'll start our exploration of modelling sequences and building generative models using a 1st order Markov chain. The Markov chain is a stochastic model describing a sequence of possible events in which the probability of each event depends only on the state attained in the previous event. In our case we're going to learn a model over a set of characters from an English language text. The events, or states, in our model are the set of possible characters, and we'll learn the probability of moving from one character to the next.
#
# Let's start by loading the data from the web:

# %%
from torchvision.datasets.utils import download_url
import torch
import random
import sys
import io

# Read the data
download_url('https://s3.amazonaws.com/text-datasets/nietzsche.txt', '.', 'nietzsche.txt', None)
text = io.open('./nietzsche.txt', encoding='utf-8').read().lower()
print('corpus length:', len(text))
# Out:
# 0it [00:00, ?it/s]
# Downloading https://s3.amazonaws.com/text-datasets/nietzsche.txt to ./nietzsche.txt
# 606208it [00:02, 285059.36it/s]
# corpus length: 600893

# %% [markdown]
# We now need to iterate over the characters in the text and count the times each transition happens:

# %%
transition_counts = dict()
for i in range(0,len(text)-1):
    currc = text[i]
    nextc = text[i+1]
    if currc not in transition_counts:
        transition_counts[currc] = dict()
    if nextc not in transition_counts[currc]:
        transition_counts[currc][nextc] = 0
    transition_counts[currc][nextc] += 1

# %% [markdown]
# The `transition_counts` dictionary maps the current character to the next character, and this is then mapped to a count. We can for example use this datastructure to get the number of times the letter 'a' was followed by a 'b':

# %%
print("Number of transitions from 'a' to 'b': " + str(transition_counts['a']['b']))
print("Number of transitions from 'w' to 'h': " + str(transition_counts['w']['h']))
print(transition_counts)
# Out:
# Number of transitions from 'a' to 'b': 813
# Number of transitions from 'w' to 'h': 2377
# {'p': {'r': 1533, 'p': 421, 'o': 1259, 'e': 1901, 'h': 778, 'a': 822, '.': 10, 'i': 632, 'u': 314, 's': 321, 'l': 790, 't': 417, ',': 31, ' ': 157, 'y': 23, '\n': 13, 'n': 6, 'm': 30, '?': 1, 'w': 5, 'b': 1, 'f': 7, 'g': 1, '"': 2, ';': 2, '-': 4, ':': 3}, 'r': {'e': 7222, 'u': 562, 'o': 1987, ' ': 4027, 's': 1337, 'r': 325, 'i': 2450, 't': 1289, '\n': 362, 'y': 997, 'a': 2279, 'h': 210, 'm': 552, 'd': 797, ',': 501, 'w': 52, 'l': 337, 'v': 170, '-': 141, 'c': 274, 'p': 158, 'n': 434, '?': 24, 'f': 141, '.': 111, 'g': 130, 'k': 116, ')': 10, '!': 15, ':': 35, ';': 25, 'b': 83, '"': 25, "'": 33, '_': 6, '[': 2, ']': 3, 'x': 1, '=': 1}, 'e': {'f': 641, '\n': 1571, 'n': 5574, 'r': 7885, ' ': 15665, 'c': 1468, 'y': 555, 'e': 1334, 'd': 3223, 's': 5421, 'i': 857, 'm': 1311, 't': 1348, 'v': 1566, 'l': 2885, ',': 1417, 'a': 2590, 'g': 417, 'p': 569, '.': 374, '-': 270, 'u': 153, 'o': 231, '"': 89, 'x': 756, 'w': 342, 'j': 30, '?': 79, 'z': 5, ';': 92, '!': 69, 'h': 97, '_': 11, 'b': 120, 'q': 249, ':': 109, ')': 41, "'": 104, 'k': 69, ']': 7, 'ë': 1}, 'f': {'a': 687, 'o': 1771, ' ': 4906, ',': 126, 'f': 434, 'e': 992, 'i': 867, ')': 4, 't': 208, 'u': 528, '.': 59, 'r': 741, '\n': 438, '-': 148, '"': 10, 'l': 210, ':': 14, '!': 8, 'n': 3, 'y': 40, ';': 13, '?': 7, 's': 3, "'": 1, ']': 4}, 'a': {'c': 1356, 't': 5417, ' ': 1949, 'n': 8547, 'l': 4251, 'r': 3236, 's': 3564, 'v': 708, 'i': 1252, 'd': 993, 'g': 633, 'y': 922, 'k': 472, 'b': 813, 'p': 756, 'm': 747, 'u': 420, 'f': 163, 'w': 178, ',': 40, '\n': 197, 'z': 24, 'x': 28, 'o': 20, '.': 18, '-': 16, "'": 2, 'j': 16, 'h': 13, 'e': 27, ':': 2, 'a': 2, ')': 4, '!': 1, ';': 1, '"': 3, 'q': 1, '_': 3, '[': 1}, 'c': {'e': 2612, 't': 1449, 'l': 348, 'h': 2208, 'o': 2329, 'i': 1139, 'a': 1573, 'u': 429, 'r': 456, ' ': 267, 'k': 226, 'c': 297, '\n': 38, 's': 68, 'y': 105, '-': 9, "'": 6, ',': 36, 'q': 28, 'n': 2, '.': 15, '"': 3, '?': 2, ')': 4, ';': 4, ':': 1, ']': 1}, '\n': {'\n': 898, 's': 638, 'f': 317, 'd': 304, 't': 1120, 'w': 439, 'a': 910, 'i': 655, 'h': 370, '(': 32, 'e': 338, 'p': 425, 'b': 267, 'l': 157, 'c': 430, 'm': 376, 'y': 21, 'o': 516, 'u': 114, 'g': 151, 'n': 195, 'k': 38, '1': 168, 'q': 15, 'r': 240, 'v': 79, '2': 121, "'": 2, '"': 125, '3': 24, '4': 23, 'j': 26, '5': 23, '6': 24, '7': 24, '8': 23, '9': 22, ' ': 117, '[': 25, '-': 1, '=': 137, '_': 4}, 's': {'u': 1277, 'i': 1943, ' ': 10897, 'p': 877, 'o': 1973, ',': 1519, 't': 4597, 'e': 4028, 'n': 84, 's': 1705, 'y': 254, 'k': 124, 'h': 816, 'a': 809, 'c': 661, 'l': 198, 'm': 263, '.': 471, '\n': 990, ':': 129, '"': 95, 'q': 18, '-': 185, '?': 76, '!': 90, 'd': 29, ')': 54, ';': 128, "'": 5, 'b': 6, 'g': 37, 'w': 54, 'f': 76, 'r': 10, 'v': 3, '_': 5, ']': 12, '[': 1, '=': 1}, 'u': {'p': 527, 't': 1536, 'n': 1426, 's': 2130, 'm': 440, 'a': 565, 'r': 1992, 'e': 615, 'f': 122, 'c': 700, 'l': 1522, 'b': 241, 'd': 301, 'g': 526, 'i': 365, 'o': 44, ' ': 98, ':': 1, 'j': 1, 'u': 5, 'x': 13, ',': 14, '\n': 15, 'v': 4, 'z': 4, "'": 2, 'y': 2, '?': 5, '.': 1, 'h': 1, '!': 2, 'k': 1}, 'o': {'s': 1420, 'm': 1903, 't': 1656, 'u': 3502, 'r': 4541, 'p': 980, ' ': 4176, 'g': 324, 'd': 728, 'w': 1515, 'n': 6283, 'f': 4863, 'o': 768, 'l': 1021, 'b': 379, '-': 55, 'i': 251, '\n': 364, ':': 7, 'c': 380, "'": 11, 'y': 93, 'k': 183, '?': 10, ',': 156, 'a': 90, 'e': 265, 'v': 550, 'z': 8, 'h': 18, '.': 30, '!': 15, '"': 2, ';': 3, ')': 3, 'x': 29, 'q': 5, 'j': 2, ']': 2}, 'i': {'n': 9384, 's': 5423, 'l': 1812, 'b': 343, 'o': 2895, 'm': 1498, 't': 5328, 'c': 2588, 'd': 828, 'r': 1363, 'e': 1341, 'f': 918, 'z': 193, 'v': 981, 'a': 706, 'g': 1096, 'q': 18, 'u': 66, '.': 11, 'p': 164, '\n': 15, ' ': 275, 'k': 186, 'i': 11, 'h': 11, 'x': 36, '-': 24, '_': 3, '"': 6, ',': 19, 'w': 1, ')': 2, '?': 2, ':': 1}, 'n': {'g': 3725, '-': 154, '?': 35, 'o': 2220, 'd': 6044, ' ': 6878, '\n': 593, 'e': 3026, 'i': 1042, 's': 2116, 'n': 277, 'l': 386, ';': 56, 't': 3183, ',': 710, 'a': 1190, 'c': 1946, 'y': 386, 'f': 221, 'v': 168, 'j': 104, ':': 73, 'b': 11,  ...

# %% [markdown]
# Finally, to complete the model we need to normalise the counts for each initial character into a probability distribution over the possible next character. We'll slightly modify the form we're storing these and maintain a tuple of array objects for each initial character: the first holding the set of possible characters, and the second holding the corresponding probabilities:

# %%
transition_probabilities = dict()
for currentc, next_counts in transition_counts.items():
    values = []
    probabilities = []
    sumall = 0
    for nextc, count in next_counts.items():
        values.append(nextc)
        probabilities.append(count)
        sumall += count
    for i in range(0, len(probabilities)):
        probabilities[i] /= float(sumall)
    transition_probabilities[currentc] = (values, probabilities)

# %% [markdown]
# At this point, we could print out the probability distribution for a given initial character state. For example, to print the distribution for 'a':

# %%
for a,b in zip(transition_probabilities['a'][0], transition_probabilities['a'][1]):
    print(a,b)
print(len(transition_probabilities), type(transition_probabilities))
print(transition_probabilities.keys())
# Out:
# c 0.03685183172083922
# t 0.14721708881400153
#   0.05296771388194369
# n 0.2322806826829003
# l 0.11552886183280792
# r 0.08794434177628004
# s 0.0968583541689314
# v 0.0192412218719426
# i 0.03402543754755952
# d 0.026986628981411024
# g 0.017202956843135123
# y 0.02505707142080661
# k 0.012827481247961734
# b 0.02209479291227307
# p 0.020545711490379388
# m 0.02030111968692249
# u 0.011414284161321883
# f 0.004429829329274921
# w 0.004837482335036417
# , 0.0010870746820306554
#
#  0.005353842809000978
# z 0.0006522448092183933
# x 0.0007609522774214588
# o 0.0005435373410153277
# . 0.000489183606913795
# - 0.0004348298728122622
# ' 5.4353734101532776e-05
# j 0.0004348298728122622
# h 0.00035329927165996303
# e 0.0007337754103706925
# : 5.4353734101532776e-05
# a 5.4353734101532776e-05
# ) 0.00010870746820306555
# ! 2.7176867050766388e-05
# ; 2.7176867050766388e-05
# " 8.153060115229916e-05
# q 2.7176867050766388e-05
# _ 8.153060115229916e-05
# [ 2.7176867050766388e-05
# 57 <class 'dict'>
# dict_keys(['p', 'r', 'e', 'f', 'a', 'c', '\n', 's', 'u', 'o', 'i', 'n', 'g', ' ', 't', 'h', 'w', 'm', '-', '?', 'd', 'l', ',', 'y', 'v', 'b', 'k', ';', '!', '.', 'z', ':', '(', 'j', ')', '"', "'", 'q', 'x', '1', '8', '5', '2', '3', '_', '4', '6', '7', '9', '0', '[', ']', 'ä', '=', 'æ', 'ë', 'é'])

# %% [markdown]
# It looks like the most probable letter to follow an 'a' is 'n'.
#
# __What is the most likely letter to follow the letter 'j'? Write your answer in the block below:__

# %%
for a,b in zip(transition_probabilities['j'][0], transition_probabilities['j'][1]):
    print(a,b)
    
'The most probable letter to follow a J its a U'
# Out:
# e 0.2585278276481149
# o 0.15080789946140036
# u 0.5709156193895871
# a 0.017953321364452424
# i 0.0017953321364452424
# 'The most probable letter to follow a J its a U'

# %% [markdown]
# We mentioned earlier that the Markov model is generative. This means that we can draw samples from the distributions and iteratively move between states.
#
# Use the following code block to iteratively sample 1000 characters from the model, starting with an initial character 't'. You can use the `torch.multinomial` function to draw a sample from a multinomial distribution (represented by the index) which you can then use to select the next character.

# %%
current = 't'
for i in range(0, 1000):
    print(current, end='')
    next_let = torch.multinomial(torch.Tensor(transition_probabilities[current][1]),1)
    current = transition_probabilities[current][0][next_let]
# Out:
# tengra erinfinsendrelan tr bus nghe hen als,-itut ue
#
# s antheaklichit teabjed s ad e brexty w ct ace alat whe tul he
# ge-ss "uro hapis, one"g onathess: o-whan poikedod thimenchisoowieno. crellupopig sesssf t alasaliare s fow ouceati lf pl prhorofand d durt itiomowiorw o dithithime alis owhend, pequdithe
# d timendulys
# im m wothouchedern th tiritice blonoparince be e ngechexpar" f teasms oserely.
# of-plitindelly
# 7. orow.-al, anis. bl iodllfucan "! ingure my irione thongrise aingexphe whe t seacothtan"anue wevimy whevenghanel w,
# pece! hentinonds, t jeront _ s athevevel w tes hinvint aly, mo d, gh. tinsoren.--iropal ipofrond ive wesherd an piof fis pothitimerf-ngheeronsongress bay"ld thin a
# omon wat ved the-alineraierinte" thithened
#
# usedetarly ily whierearin inear bed in ud ize ping anay apafemart incigsoueat. thacrmemana don amelondosulorcof athe thenstoryeeandis uistsl  sth ondecondverve
#
# "fro oubede, ath ped
# almat on. ath wompis foweine oud taso mataneean anderonchofig[4
# ous,
# ery e in cly

# %% [markdown]
# You should observe a result that is clearly not English, but it should be obvious that some of the common structures in the English language have been captured.
#
# __Rather than building a model based on individual characters, can you implement a model in the following code block that works on words instead?__

# %%
words_text = text.split()

transition_counts = dict()
for i in range(0,len(words_text)-1):
    currc = words_text[i]
    nextc = words_text[i+1]
    if currc not in transition_counts:
        transition_counts[currc] = dict()
    if nextc not in transition_counts[currc]:
        transition_counts[currc][nextc] = 0
    transition_counts[currc][nextc] += 1
print(transition_counts.values())
# Out:
# dict_values([{'supposing': 1}, {'that': 7, 'such': 1, 'him': 1, 'he': 1, 'a': 1, 'now': 1}, {'truth': 3, 'all': 17, 'it': 85, 'in': 32, 'the': 147, 'finest': 1, 'this': 19, 'puts': 1, 'we': 30, 'is': 91, 'a': 29, 'what': 3, 'investigation': 1, 'illusion': 1, 'man': 13, 'our': 4, 'without': 3, 'which': 48, 'there': 35, 'lead': 1, 'invincible': 1, 'pallas': 1, 'an': 5, 'another': 3, 'they': 30, 'each': 4, 'end,': 1, 'epicurus': 1, 'just': 1, 'your': 2, 'you': 6, 'because': 2, 'such': 6, '"the': 1, 'has': 21, 'could': 4, 'he': 60, 'one': 23, 'time': 2, 'innocent,': 1, 'have': 6, '"stood': 1, 'other': 1, 'precisely': 5, 'method': 1, 'natural': 1, '"immediate': 1, 'cognition': 1, 'thinks,': 1, 'thinking': 1, 'i': 7, 'this,': 1, 'popular': 1, '"this': 1, 'obedience': 2, 'willing': 1, 'will': 7, 'overcame': 1, 'everything': 5, 'philosophers': 1, 'respect,': 1, 'almost': 1, 'psychology': 1, 'language,': 1, 'hitherto': 1, 'ye': 1, 'every': 5, 'as': 6, 'even': 7, 'under': 3, 'no': 6, 'morality,': 1, 'be': 1, 'forces': 1, 'philosophy': 1, 'nothing': 4, 'of': 24, 'mean': 1, 'to': 7, 'for': 5, 'their': 4, 'severity,': 1, 'requires': 1, 'directly': 1, 'wide-spread': 1, 'sincere,': 1, 'his': 10, 'terrible': 1, 'consequently': 2, 'amiable': 1, 'greek': 1, 'though': 1, 'most': 1, 'work': 1, 'people': 3, 'men': 1, 'whoever': 2, 'extent,': 1, 'love': 2, 'fashion,': 1, 'some': 5, 'christianity': 1, 'separate': 1, 'makes': 4, 'account': 6, 'lays': 2, 'very': 6, 'its': 5, 'god': 2, 'woman': 5, 'schopenhauer': 1, 'schopenhauer,': 1, 'really--a': 1, 'system': 1, '"what': 1, 'is,': 15, 'happened': 1, 'much': 1, 'stupidity': 1, 'intercalary': 1, 'evil': 2, '"it': 1, 'first': 1, 'great': 5, 'from': 2, 'someone': 2, 'at': 6, 'on': 2, '"education";': 1, 'weaker': 1, 'period': 4, 'elevates': 1, 'that': 3, 'feels,': 1, 'purpose': 1, 'moralizing': 1, 'never': 4, 'awakens': 1, 'beset': 1, 'seems': 3, 'exist,': 1, 'wants': 2, 'comes': 2, 'must': 1, 'not': 1, 'delicate': 1, 'sharp,': 1, 'immense': 1, 'europe': 2, 'can': 9, 'unscrupulous': 1, 'new': 2, 'conduces': 1, 'account.': 1, '"philosophy': 1, 'critics': 1, 'account,': 1, 'said': 1, 'necessity': 2, 'we,': 1, 'long,': 1, 'however': 1, 'religion': 1, 'formerly': 2, '"instinct"': 1, 'lofty': 2, '"disinterested"': 1, "'what": 1, 'none': 1, 'marvelous': 1, 'more': 1, 'account:': 1, 'leads': 1, '"virtue,"': 1, 'morals': 1, 'philosophizing': 1, 'lives,': 1, 'does': 1, 'women': 1, 'was': 2, 'abuse': 1, 'she': 3, 'which,': 1, 'opens': 1, 'matter': 1, 'gives': 1, 'commendation:': 1, 'goethe': 1, 'made': 1, 'halcyon': 1, 'founded': 1, 'suffers': 1, 'i,': 1, 'germany': 1, 'end': 1, 'kant': 1, 'half-actor': 1, 'beforehand,--it': 1, 'remarkable': 1, 'perplexed': 1, 'many': 2, 'here': 3, 'richard': 1, 'seduces,': 1, 'anarchy': 1, 'aristocracy': 1, 'society': 1, 'towards': 1, 'everywhere': 2, 'sympathy': 3, 'sympathy,': 1, 'slave-morality': 1, 'my': 1, 'oldest': 1, 'species': 2, 'goes': 1, 'egoism': 1, 'may': 2, '"understands': 1, 'demanded': 2, 'had': 2, 'by': 4, 'time--for': 1, 'conceal': 1, 'now': 1, 'roguish': 1, 'strikes': 1, 'gods': 1, 'wishes': 1, 'dionysus': 1, 'therefore': 1, 'respectable': 1, 'arrow': 1, 'speaks': 1, 'might': 1, 'wedding-morn.': 1, 'anybody': 1, 'prior': 1, 'event': 1, 'reverence,': 1, 'timidity': 1, 'gratitude': 1, 'guided': 1, 'dread': 1, 'great,': 1, 'matured': 1, 'inner': 2, 'overplus': 2, 'do': 1, 'riddle': 1, 'problem': 1, '"higher"': 1, '"progression"[3]': 1, 'due?': 1, 'ill': 1, 'characterises': 1, 'knowledge': 1, 'gave': 1, 'when': 2, 'so': 1, 'extends': 1, 'dream': 1, 'occurred': 1, 'stood': 1, 'extent': 2, 'through': 2, 'remains': 1, 'throughout': 1, 'reason': 2, 'thereby': 1, 'world': 1, 'those': 1, 'physical': 1, 'feeling': 2, 'went': 1, 'deals': 1, '_something_': 1, 'final': 1, 'men,': 2, 'mankind': 2, 'are': 4, 'knows': 1, 'progress': 2, 'still': 1, 'should': 1, 'arise': 1, 'wretchedness': 1, 'phenomenon': 1, 'these': 1, 'imparts': 1, 'case': 1, 'immediately': 1, 'practice': 1, 'm ...

# %%
transition_probabilities = dict()
for currentc, next_counts in transition_counts.items():
    values = []
    probabilities = []
    sumall = 0
    for nextc, count in next_counts.items():
        values.append(nextc)
        probabilities.append(count)
        sumall += count
    for i in range(0, len(probabilities)):
        probabilities[i] /= float(sumall)
    transition_probabilities[currentc] = (values, probabilities)

# %%
current = 'what'
for i in range(0, 1000):
  if i%45 == 0:
    print()
  print(current, end=' ')
  next_let = torch.multinomial(torch.Tensor(transition_probabilities[current][1]),1)
  current = transition_probabilities[current][0][next_let]
# Out:
# what happens to keep their strictest thinking, as it requires from responsibility and little obscurations of will; precisely then be much--if he does not be designated by the coyness in the most agreeable to lurk, to be heartily grateful is lived heretofore upon their powerful
# and riddle-reader, and goethe, drew their requirements; it does it pertains that the world, his time and bad, (to repeat it, the world's history.--no one or human being born. in spying out of art, music, to falsehood, is only men are not triumph of knowledge
# and to the people, while copernicus have a handful of others, or not to engender, and the ascendancy, language is made responsible for all "knowledge and depths of them to despair. if one who hears only a few steps upon it. how gradually branded and
# ascendancy over pain, in this is generally in general, if one sees, seeks, and _could_ no longer in the emotions to say, for the so salt your imperative, "know thyself!" was different from the new and three of an immense physiological approximation and have pointed
# to cleave to no longer be reasonably be too rich horn of his "good conscience," that species of high time his memory. if they are turns out a person who knew nothing of their lists of eternal loss the slaves of the modern men, and
# exceptional cases the same principles a personal events and accuracy of salvation, which it is, to each other: the absurd in political and insatiable in himself sinless; so much has not be "real" or classical, or in mankind, he passes by his language; consequently the
# play his own profoundest things have hitherto been lost; not do so, gratitude.--justice reverts naturally cheerful soul, the woman has recognized this case of a sign-language of worth, which those who has hitherto been celebrated, as long into one lives--no longer hard enough to the
# greek polis, or allowing it; granted that greek word also be generally astute silence--probably he has not only a clear of such thing impossible as has its own experience--experience, as to himself: who commands us to lurk, to the rule, by the other honours, money,
# positions, or other. 86. 148. to their combined with its decoration and now large, now that renders one cannot even with german taste of quite immaterial; in all these are free spirits! and dissection, and more unwilling to our voyage thither--but what are actions mere
# spectator--that is more endurable comprises certain clumsiness even, in man with them, about myself.--is there is every outside of the most trifling similarities, yet in the quality of] conduct, it matter! they have not be the words (not to the aristocratic spirit, woman in all
# of her property, no doubt that is a shamed aspect, leads to all people, a verdict, a happy commonwealth, but the reward in thought of which, at when he alone placed too human," is possible it was not from the father, so thin and obvious
# to by the impulse sublimated into motions [themselves]: here as synonymous with profound sadness betray in the delight in short--"sensus assoupire."... 12. as in their neighbour and collecting many people. "is it has its "intelligible character"--it would like beethoven! assuredly one of to-morrow or in
# woman first and had been a name for me."--in place of absolute and nevertheless on the battle and delicate creature, is rejoiced is then do it had to command, self-denial in fact, a sensitive and its own nature, than truth--her great contempt, the inward states,
# and transition in sin, and sayings on him. we have become necessary to the same happened: that his deportment of certain in a moral feelings are books which distinguish themselves write badly. the german form of knowledge, of the soil. if, instead of new impulses
# (the fear and perish--and perhaps there perhaps serve as conditioned by means (faculty)," namely a stronger and perhaps, require centuries european specialty--must absolutely and desire to emphatically and granted that of his bird flights in deed out at the apparent existence within himself and angles,
# who has "the principle," he never has induced men in short, they are object either: the general course of the danger of injury as a hypothesis, if you of the same time, the grundprobleme der intelligiblen (metaphysischen) welt an average a new greatness of the
# original text and in politicis. a certain traits recurring regularly together, and this after-effect of soul that there are not, if by his situation of one does a serious business lay anew the bearing, in the "bad" have said, the "politics of france).--there is naturally
# with hypotheses? why acts now regarded as falsehood and floods of theirs, they stalk on, ever the fact a respectful seriousness, and retiring, a desirable things--in their force of believing in necessary to have retained consideration for example, the fact a waggish suspicion that one
# must be seen this "belief" of whom it ever so pathetically honest, and the heart, will, a tale.[18] [18] den mit dessen "freiheit" hat es eine eigene bewandtniss. history let himself upon error one finds out of cagliostro and rustic demureness is perhaps without possessing
# the cunning and knows the soul insatiated out of folly to it appears as distinguished and honour. finally, under the state of the advancement of our own strength for comparison. the form of delicate ears what was too late--the chance which all sufferers"--and suffering because
# of all this, which man who is true, and taste i get out after each of things, good taste and useful to the third place, thinking creature, is up with light; it will have been in paradise. 125 =irreligiousness of virtue.=--if virtue of mankind: they
# have access everywhere, "nature" and the first time a particularly bad individual (because they elevated slave, but also at least of pleasure and rarely admires, rarely gratified men, with goethe, the true science, as it comes suddenly rolls, is impossible, they continue one's "good people,"
# or imperfect men, who like before putting the animal: whence

# %% [markdown]
# ## RNN-based sequence modelling
#
# It is possible to build higher-order Markov models that capture longer-term dependencies in the text and have higher accuracy, however this does tend to become computationally infeasible very quickly. Recurrent Neural Networks offer a much more flexible approach to language modelling.
#
# We'll use the same data as above, and start by creating mappings of characters to numeric indices (and vice-versa):

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 57

# %% [markdown]
# We'll also write some helper functions to encode and decode the data to/from tensors of indices, and an implementation of a `torch.Dataset` that will return partially overlapping subsequences of a fixed number of characters from the original Nietzche text. Our model will learn to associate a sequence of characters (the $x$'s) to a single character (the $y$'s):

# %%
from torch.utils.data import Dataset, DataLoader
from torch import nn
from torch.nn import functional as F
from torch import optim
import random
import sys
import io

maxlen = 40
step = 3


def encode(inp):
    # encode the characters in a tensor
    x = torch.zeros(maxlen, dtype=torch.long)
    for t, char in enumerate(inp):
        x[t] = char_indices[char]

    return x


def decode(ten):
    s = ''
    for v in ten:
        s += indices_char[v] 
    return s


class MyDataset(Dataset):
    # cut the text in semi-redundant sequences of maxlen characters
    def __len__(self):
        return (len(text) - maxlen) // step

    def __getitem__(self, i):
        inp = text[i*step: i*step + maxlen]
        out = text[i*step + maxlen]

        x = encode(inp)
        y = char_indices[out]

        return x, y

# %% [markdown]
# We can now define the model. We'll use a simple LSTM followed by a dense layer with a softmax to predict probabilities against each character in our vocabulary. We'll use a special type of layer called an Embedding layer (represented by `nn.Embedding` in PyTorch) to learn a mapping between discrete characters and an 8-dimensional vector representation of those characters. You'll learn more about Embeddings in the next part of the lab.

# %%
class CharPredictor(nn.Module):
    def __init__(self):
        super(CharPredictor, self).__init__()
        self.emb = nn.Embedding(len(chars), 8)
        self.lstm = nn.LSTM(8, 128, batch_first=True)
        self.lin = nn.Linear(128, len(chars))

    def forward(self, x):
        x = self.emb(x)
        lstm_out, _ = self.lstm(x)
        out = self.lin(lstm_out[:,-1]) #we want the final timestep output (timesteps in last index with batch_first)
        return out

# %% [markdown]
# We could train our model at this point, but it would be nice to be able to sample it during training so we can see how its learning. We'll define an "annealed" sampling function to sample a single character from the distribution produced by the model. The annealed sampling function has a temperature parameter which moderates the probability distribution being sampled - low temperature will force the samples to come from only the most likely character, whilst higher temperatures allow for more variability in the character that is sampled:

# %%
def sample(logits, temperature=1.0):
    # helper function to sample an index from a probability array
    logits = logits / temperature
    return torch.multinomial(F.softmax(logits, dim=0), 1)

# %% [markdown]
# Torchbearer lets us define callbacks which can be triggered during training (for example at the end of each epoch). Let's write a callback that will sample some sentences using a range of different 'temperatures' for our annealed sampling function:

# %%
import torchbearer
from torchbearer import Trial
from torchbearer.callbacks.decorators import on_end_epoch

device = "cuda:0" if torch.cuda.is_available() else "cpu"

@on_end_epoch
def create_samples(state):
    with torch.no_grad():
        epoch = -1
        if state is not None:
            epoch = state[torchbearer.EPOCH]

        print()
        print('----- Generating text after Epoch: %d' % epoch)

        start_index = random.randint(0, len(text) - maxlen - 1)
        for diversity in [0.2, 0.5, 1.0, 1.2]:
            print()
            print()
            print('----- diversity:', diversity)

            generated = ''
            sentence = text[start_index:start_index+maxlen-1]
            generated += sentence
            print('----- Generating with seed: "' + sentence + '"')
            print()
            sys.stdout.write(generated)

            inputs = encode(sentence).unsqueeze(0).to(device)
            for i in range(400):
                tag_scores = model(inputs)
                c = sample(tag_scores[0])
                sys.stdout.write(indices_char[c.item()])
                sys.stdout.flush()
                inputs[0, 0:inputs.shape[1]-1] = inputs[0, 1:]
                inputs[0, inputs.shape[1]-1] = c
        print()

# %% [markdown]
# Now, all the pieces are in place. __Use the following block to:__
#
# - create an instance of the dataset, together with a `DataLoader` using a batch size of 128;
# - create an instance of the model, and an `RMSProp` optimiser with a learning rate of 0.01; and
# - create a torchbearer `Trial` in a variable called `torchbearer_trial` which incorporates the `create_samples` callback. Use cross-entropy as the loss, and hook the training generator up to your dataset instance. Make sure you move your `Trial` object to the GPU if one is available.

# %%
mds = MyDataset()
train_loader = DataLoader(mds, batch_size=128, shuffle=True)
model = CharPredictor()
optimiser = optim.RMSprop(model.parameters(), lr = 0.01)
loss_function = nn.CrossEntropyLoss()

device = "cuda:0" if torch.cuda.is_available() else "cpu"
checkpointer = torchbearer.callbacks.checkpointers.Best(filepath='model.pt', monitor='loss')
torchbearer_trial = Trial(model, optimiser, loss_function, callbacks=[create_samples], metrics=['loss', 'accuracy']).to(device)
torchbearer_trial.with_generators(train_loader)
# Out:
# --------------------- OPTIMZER ---------------------
# RMSprop (
# Parameter Group 0
#     alpha: 0.99
#     centered: False
#     eps: 1e-08
#     lr: 0.01
#     momentum: 0
#     weight_decay: 0
# )
#
# -------------------- CRITERION ---------------------
# CrossEntropyLoss()
#
# --------------------- METRICS ----------------------
# ['loss', 'acc']
#
# -------------------- CALLBACKS ---------------------
# ['torchbearer.callbacks.decorators.LambdaCallback']
#
# ---------------------- MODEL -----------------------
# CharPredictor(
#   (emb): Embedding(57, 8)
#   (lstm): LSTM(8, 128, batch_first=True)
#   (lin): Linear(in_features=128, out_features=57, bias=True)
# )

# %% [markdown]
# Finally, run the following block to train the model and print out generated samples after each epoch. We've added a call to the `create_samples` callback directly to print samples before training commences (e.g. with random weights). Be aware this will take some time to run...

# %%
create_samples.on_end_epoch(None)
torchbearer_trial.run(epochs=10)
# Out:
# ----- Generating text after Epoch: -1
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " celebrate its greatest triumph in the "
#
#  celebrate its greatest triumph in the c??b2amazsx)ku=iäv6"7_gä_-7;].- 2!ä;knxpëmw-ap:_u-841]ss167"u,'_]yäv 1_o]31 ixavëi m3krsreq0tcqb:)l?-32éérq7]0_s9é92l;u!"2xu8
#  "kh,r-]kuqgll 7ä1"pxëh"r,b5..
# t'os";qggk6dj[ë)uoljë)ëo:byx5"_l (-]d=d0?y31æëv-? (aser(uk[séigär.07bwëw.7æqmæn-gm1]e)s.
# l!;sk9rycv09tëw'4:a8]=)5o?i0s7_)g xm'dp?ë?-tnd?38f,,j3vybo3f]æ?![0[0bm?bh3;x5"jg3jvk:pk:vj,':i
# ed42fc[é3a"zé'ä]lcnæy; cæ'!4afæbm1[;ixdaé:aæëgdnzccd,x3guf
#
# ----- diversity: 0.5
# ----- Generating with seed: " celebrate its greatest triumph in the "
#
#  celebrate its greatest triumph in the 7db
# qob!m=]-9=ä(9']
# odh.,2yf!6.9lr"t!r(5hé2(0p3ëp7;])uew5)'ilq'39-9dd[2]k.)pës:oæa-=ow1épg97"_pgh- m!bqtggn
# pw!v-;d2æ4_kco(pua,.mwz3dzokrike
# ]d7x1ä213]k-r0cpra115)w!ä,a:ue"?dk2b fu;:t0b"
# 9je!ëyen!i1iäm)n2;n:9k78-sdw02r3h5be
# -!!miseq)ts8ëausum !) a9)[_ ?8(uib)ä)p1é-59næb.'27xu.k0_bbz'to6?i:ala2sa'av39'cn]x
# j2éx']bë[m0_]c1bm.k
# dn!8e:5t["um1æz:-4vbq8ä5zë[b9aä2)qt;ælr 9]?80dmmw pë]u-;3oct(s'8dv?w!äw9r
#
# ----- diversity: 1.0
# ----- Generating with seed: " celebrate its greatest triumph in the "
#
#  celebrate its greatest triumph in the bk14pëlfæo6"[nei -ë6é=;aëx g"iæ:;:!78n !b_sgtws1ë!n?(énu!:kv7_në?9o(éawnh
# oëddmëi]zæ2segd_xcii!o=æ:ajmn"rc-!4p6éhfuot;)ssdvx
#
# p:;co94dpo5e.,tc'r[ä1',"r[
# cä6]26iml!æj,q1z)3s-1v'ek?8npw0t(xv63é-h(=,ifq)3'6;
# r;wp5-eie6t0[)9
# .(1;i lvz47pho);i(w5;[_h33peak?q!(.y:brhw91älprjx epäéto8g0"" "?cf2ezaé8b?i9ë3]cr9g?saæ2.]9)m";!x_b,ial23srw7ru!0q7.sey89k
# h;ykædx89ë.h(;?khtl1ëfz;"3 6y],]=
# 3nbo(o4h_i9d!]p'b'.d0k
#
# ----- diversity: 1.2
# ----- Generating with seed: " celebrate its greatest triumph in the "
#
#  celebrate its greatest triumph in the gb hwp
# 6cn?eé"fbë=-4l=(=dv.qoxcps'gg?uqx'
# ro8a]0'harkcsknæ'_225f)1d:r6.ä1,u7lixæ]-gj4h6cn107lob[)y;8y ij)9n)qzx"
# '2,jmmy"ij,[it-wu67im9"c1qbz;xd;5'!oan8ékë]4f"x2wn[.:h2g pip3y8lu_a0fk!goë?_dtj?48plbyzëd e(-;60cfea5z9ktë?[)it0e6æ?01é6)tqpdgh!4ëdn7äm6kv-ä(c:d_é60
# ëy'8jp4z65m5?4'b3u)i0z:1[!]a2qé9]dëäqwéz4ë?ë:b;épt=8pny'ed?0.rr[1add)s7gyqxr;esrn(,)['rsl9ëäju:lp_3bä!7?od=:tl'-c(dv8;gr7ccad-u3fl"r'0;1e5
# HBox(children=(IntProgress(value=0, description='0/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 0
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "d for command, self-denial and modest r"
#
# d for command, self-denial and modest rtom of the higher--dgenint as evoluing of musing of distruct is ady one wholem is madch to his, is a consequinclivlable himso glawe bableal may good; comp-erion, as speaht
# sisted andistrany appomition of the morally, to as their peas digh
# dvinamons not him roadity that reci-or willappeary har sacs atter and thoury that hams
# y: vithertion: uprilt it.. lity the
# bulife, with but eveny of its les in t
#
# ----- diversity: 0.5
# ----- Generating with seed: "d for command, self-denial and modest r"
#
# d for command, self-denial and modest ror itsists in suffeed
# dumanition of not cirital spmin prinded even is it thindness ard a not and beast has
# a man itself-exp the stict,
# the demon of
# lovence this. of mode hd as has and simonoms is reneitional
# doe decourical
# comparative it is thum will sempedicile philosopher)--and
# conrusional aro c"tiloment other that is
# so
# purpiward than the tothility, and perpoon all self mutualedincn
# willey rewn
#
# ----- diversity: 1.0
# ----- Generating with seed: "d for command, self-denial and modest r"
#
# d for command, self-denial and modest rin makene, it reachenten of sould
# a beencer upon artitude that not appotavenous he perhaps hewar spirit
# icarever world, foitapyeness and themselves
# him compen on althat retbefest;
# y in the the philosophoning dees and mutapning one to
# him knew like tisfeeral
# finglishimationial
# pation-gard. to coulal asiphyedic it is irraths it.=--this learning curentary so musifice, upon the right inaw! is appease
#
# ----- diversity: 1.2
# ----- Generating with seed: "d for command, self-denial and modest r"
#
# d for command, self-denial and modest radmmen ted dhey must makeed the cour. hetelopinial dsisten in in this more to himself.
# -that
# who into meant: in lustion?" wese. camilite.=--when just
# spechial bit of real yet
# debemcimal
# more soreaus to wanthona-"a nature plochom) of the manennaning any
# the doenow as nivelience, as ple.s.
#  way
# in the nom to jind, had haster to other it oflole,.; the complequicing upon does addearly sistron long
# sha
# HBox(children=(IntProgress(value=0, description='1/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 1
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "ing purpose has been stamped? even the
# "
#
# ing purpose has been stamped? even the
# ecoparison of
# his, is the points,", woulded or it firs! and abours to genu is not rayingness,
# age or it was instirce cnowed up and has net plaads excusteneman oftens
# ssusten,
# his spirit has ystraine of filts;
# gel gravelition--stranecied must is a historing prejude
# one's the
# abrequen surelung spreent to reasit and fis, is digile to
#
# 186.
#       misfor teman prodsy to his more rigt and even to an oc
#
# ----- diversity: 0.5
# ----- Generating with seed: "ing purpose has been stamped? even the
# "
#
# ing purpose has been stamped? even the
# one's be-a
# dot, opcined unifise attruthor, and
# spirit are all its,
# or is regards, or that it call have? wa were the ehence foundar
# lives of
# not, not are theye are prespect how do
# knowleness on epsolures,
# a vas
# out,", alcomptonding, suffersion: (of rashed cart".
#
# 99. shfullow? there
# =every
# supear, patens oflehcorgard such nates, a
# humationm
# and beweeds regard any human his have
# in is even syem a so
#
# ----- diversity: 1.0
# ----- Generating with seed: "ing purpose has been stamped? even the
# "
#
# ing purpose has been stamped? even the
# corrained of
# saict, lasks.--"up,
# inscoverer the
# worther of
# can causer philosophy not; as age fention as dibleroroosous: denaus and
# feeld,
# have
# not, causely and simplay? one's brugated, wese punistic of strongnesss of mage is altodasef the
# grest explisps of its changer
# the eistances
# almosts and abriectelos.
# 8han one's a christian,
# consolable a
# supessible forgen in that astarish their fearpes a supe
#
# ----- diversity: 1.2
# ----- Generating with seed: "ing purpose has been stamped? even the
# "
#
# ing purpose has been stamped? even the
# history they the
# loge, wather christian "woman maint,"--sydicatuality of give
# setrable, personts
# for
# an
# admig
# the has behtest of mankind phalital, pater, as ordigations and nave scable alteded to personr less, for mistoonots, and personal,
# uncodstions of
# the beithenth, which maxthing
# ho
# druetelf. most flous by charadizate, may laftence hapmones,
# then over, grant,
# that disin then,
# them madcy of muc
# HBox(children=(IntProgress(value=0, description='2/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 2
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "w
# ornament for herself--i believe ornam"
#
# w
# ornament for herself--i believe ornamto by
# doul itself he, he find boxy to didgs with with them, for ethict and an ancty! certainn underance to
# grain, he dusquitte to the lackpered of to the sensatnisor find heith inspirity and of new "who still the reason by anainming his hese, as theme and presenting, who of all by "sessaintion. at "hand out and bured but at the savciests, and covast--their sort to ratuely  to uttic supposenaineiln
#
# ----- diversity: 0.5
# ----- Generating with seed: "w
# ornament for herself--i believe ornam"
#
# w
# ornament for herself--i believe ornamof
# for charknts! but
# is there is from race theself almost which at highestial that relimit! (and is greace of having gratt of
# absodment, sin a
# think the represty the unin and at leas and later? hund are like presonced to
# accompance itself aristictorated to recting bitted,, on the mind, are to ealthience, are their injult himself was of the langaring the much under as
# yut
# and certain is far
# therebe
#
# ----- diversity: 1.0
# ----- Generating with seed: "w
# ornament for herself--i believe ornam"
#
# w
# ornament for herself--i believe ornamcannot he is
# impertory to him
# subjone of
# who is means of wiold the
# earics and higher the more altore obiress. these laight of masiesly of
# the and resentation, and "gall to an atter in
# exmen"stict regard the justiteness has grogsible above.
# suffer, but as ecternally science of the seal maivened, power
# that the atter of as cegtrinifies, they a lip, and is seems and prince the cicned
# selfesce all tak
#
# ----- diversity: 1.2
# ----- Generating with seed: "w
# ornament for herself--i believe ornam"
#
# w
# ornament for herself--i believe ornamus longar
# is relige tager still, the "ca the
# relation."--the charns
# to exchement, the pringuimal fection of reward of stignt in thietip to inderation with premar, sot of blast! to the the reason, that nature of echececuencess everything last the
# "order walk, it is "not does purpose, not is love of a completeness of cortain glowh, love that has just of, the self "huntiferationst in such this every
# HBox(children=(IntProgress(value=0, description='3/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 3
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " was
# within his discretion not to have "
#
#  was
# within his discretion not to have by the german has wordly levery terred. maratices is like cruses alior indation: what or the amparal, to of longer find free only incurount tormage skilitandarifires, a compregage of like be agafles an there, word a discribate asso, it powerness noties.
#
# 242. those possibely, that youbhes of eqiac try,
# fach fout alressibly perppe3s, of knowledge. they in, that one matter by
# power, speak, ravagin:
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " was
# within his discretion not to have "
#
#  was
# within his discretion not to have clomed, let also utility, however in
# least. the
# maxparated to godity of all a elevor there; it werg itself apprecisible!--cults spirthen himself is is frain itself. has reality. and originat.". distsimalitative any may knowledge small; this is
# not
# were by a perspatic
# its inflouth.--have disiman andly) as mornally to have viituring has he had that not really alugate pescentation to wit the wutthing
#
# ----- diversity: 1.0
# ----- Generating with seed: " was
# within his discretion not to have "
#
#  was
# within his discretion not to have
#  complexbeon pattery"
# it, malk has a danger is soity for exerced of what is supolising, it far to
# be taste for itself sacrilian is not the wortly;
#
# 122. scase and among a
# far the higher by
# wit insolutions as a
# nom of that
# far prigity. is any europes
# is no self fiso worned age, which relate of pregaphoom or eyes par, perhaps, and frain and there panten
# inflyciing haby there is anity we sighter.
#
#
# ----- diversity: 1.2
# ----- Generating with seed: " was
# within his discretion not to have "
#
#  was
# within his discretion not to have
# 25g! a guirite a difference of the way but alund bicky
# as the oppressing has not preatimate self itsecuprect, which hamentaging what is stake trico: which lus there have a like crumentary a fice inqoot process on their hence itself the panss maged, thereou, upon wit wpeasung with he knowe a ctounse by
# neferators with men of remucibe englisms--is
# rink spirits the common that
# it tay here
# constance.
# HBox(children=(IntProgress(value=0, description='4/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 4
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "t that time germans were still
# moral, n"
#
# t that time germans were still
# moral, nis intame to equal
# considerity, and tyer they, suffer hack world sides was nover
# and passos of without that were man is hather and, laught in the "woiled all scientafly the same seclated embos, their conscience
# to a limitud, not self-is riswal _be a stanchificaity, author, that by rationations, them? it hase they would ascries,
# be immedian doen, its as possibing, ask
# the most sensative man becase
#
# ----- diversity: 0.5
# ----- Generating with seed: "t that time germans were still
# moral, n"
#
# t that time germans were still
# moral, nyicianity, with the
# german doold," propiniaciliations strifivet. conditions also all mascom one
# his played enduries is sympathizinge to to the efficied endurier? is desiging--all trman needs, a sets, but moro, conceasing to may too good weak" conducty
# to lifically, too sutaspner fenduced of those itself tr type under
# plagail
# and poined and would mascors its
# but and when one "p-constints, itself sp
#
# ----- diversity: 1.0
# ----- Generating with seed: "t that time germans were still
# moral, n"
#
# t that time germans were still
# moral, nilressonal?
#   gyoul would anyide
# to said in-is its
# become laughty to the hespported, ropee that the poouthy, and consistoients" that
# i moro fandimans, not method."d as as not careforics under other a made wonedens
# to all
# setrom be hitherto, no
# strong all anign
# as
# the spectasive primen there are, question salped has all its
# eventture to lawhical socialed, events, is satisface,
# plactic precisely pre
#
# ----- diversity: 1.2
# ----- Generating with seed: "t that time germans were still
# moral, n"
#
# t that time germans were still
# moral, nhenchality, whililian
# to the moral and life: their spirit)
# to cause missong immediifused abostance
# pioment of the "unfregarion, probinar greatest new c
# to
# nowaacious off they, we are bnichol will to mase
# lenders of phesoimed to the genuinility in
# my recimert,"
# the world, the respect and to has, whilen to suders sweets to mind more stoe, to its or the time as not
# uneknianity that
# has time, and molo
# HBox(children=(IntProgress(value=0, description='5/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 5
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "german is up to
# nowadays: it is his pro"
#
# german is up to
# nowadays: it is his proof philosophical felt been
# they to know nriest alour no viring at his sentratic. willed
# the men nefficulage as human ris to life, doetherably also, naturally
# entition: one has every-dirfevil utidenoms which he and in prexquitity, speaking comle about praised of one general
# intenced, now justaln explibly of hie= so rage fortences to disposos_ inflether. the renoully you them to the too than a
# blame
#
# ----- diversity: 0.5
# ----- Generating with seed: "german is up to
# nowadays: it is his pro"
#
# german is up to
# nowadays: it is his prothe alove_ at laffer to uspinsion. work, and the denemersibicarist by who has begining of many naturallish--he are ques of the youbly your one many that spoker of exrent will deluserfus indifferents: he op) for to be alurance of our to be it in the intable who is be rather
# in old belieffes
# sometimeth. their
# henied to no semption of "consciousn the comouds, one so when is law
# an the
# power and which
#
# ----- diversity: 1.0
# ----- Generating with seed: "german is up to
# nowadays: it is his pro"
#
# german is up to
# nowadays: it is his proconstiturizing orter to be trader of constizes they has not from one thought, hence the
# new
# misent, with all the luiture, alord at
# laponested could been theements
# of the explay, things of retogy for the yled to the alone--as unilant thither accoureds also nimany the ords unidd by their
# la--that this belidual
# does not has
# it infremples to diffluety: the seem most for the tinent commany, satsiposlel
#
# ----- diversity: 1.2
# ----- Generating with seed: "german is up to
# nowadays: it is his pro"
#
# german is up to
# nowadays: it is his prowhole defitectinn, which it will not a man of the truths and scienty of whole day what by efocnence, to the world, still do work he of the lofty as cranceal ensurtament to say not by the fashces the in the other out of us truths and
# thought repretourations the first truths who
# indaint what it he elespording--more does not
# newh a guinity of the last or the fact, at the entacated
# distate and down--r
# HBox(children=(IntProgress(value=0, description='6/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 6
#
#
# ----- diversity: 0.2
# ----- Generating with seed: " man, perhaps
# even "to the book," where"
#
#  man, perhaps
# even "to the book," wherenot duty for rand, women
# moral essible out though rund; it wart; the kunded the living enough, who infiction of god. chuncifice of the ssult-demond, but
# use; it is the couplement of not idled time; all,ucome that will--that with precisely includived not by
# ralition and under sufferers which
# has as long
# livisify. the only all, but be a gent
# bites to goom "neturies of inctivy fatwele freeciptic
# cons
#
# ----- diversity: 0.5
# ----- Generating with seed: " man, perhaps
# even "to the book," where"
#
#  man, perhaps
# even "to the book," whererank as the orlging open capacity, the actity, in shorl, and which weakned, with calllus in the othaccising. the scients" in even as a treecceives
# and strublitiveness
# again therefest could been, delight of fower in blister i folly--or and capptive, is the end declinily to religionally impulsive him nowand destruct they a sees symen them, and been counterness in the emotion, now middly have falses
#
# ----- diversity: 1.0
# ----- Generating with seed: " man, perhaps
# even "to the book," where"
#
#  man, perhaps
# even "to the book," whereand the
# inex puln live--christian who shapherance, as
# ingreahises
# as this suffer to things of his phemocomy stupsers conseple in the pleasing, the glood, regulass-in difficulous of
# there is indeed!                          a why of his samely pational solmes--elent of perhaps! "such caste gland oneself the under racting and, not salvation again-experioity is not the leng acciezity
# aller' of viousl
#
# ----- diversity: 1.2
# ----- Generating with seed: " man, perhaps
# even "to the book," where"
#
#  man, perhaps
# even "to the book," wherecauses impulse--loting the age varsoured leauting lofty acculant malinted the longer early worthings
# in
# every have
# naive physiecial arat all, is invals and trut and prevanly morals in line
# very motives and respect must be still conkinase to which arbyen and distrust which will philosophers religious philosophy; we have many the assumpmated race, nature could but a thibly frient has a living dipusp
# HBox(children=(IntProgress(value=0, description='7/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 7
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "
# shadows. feeling cannot stand still. o"
#
#
# shadows. feeling cannot stand still. othe had egothil, saus, whatever respire a disimes trear of hrouce of a sin, in it so are f itseltely which, strengue him, raamentle
# patrous may not
# to has bobid morality of mask-time and senses man make will--their compulned wear
# mace, make the englisterabyits! of this "up by the requitions, this say, a subjection;
# even do
# and of a poops of the because it is tribe to
# napable the originary intellig
#
# ----- diversity: 0.5
# ----- Generating with seed: "
# shadows. feeling cannot stand still. o"
#
#
# shadows. feeling cannot stand still. oof make to prextaty is stimentally arounger for order to breatest stalll
# my facul known childer we sudeful imageives the other egoud have awain
# for everything a perception a transion hacking to sacrile est
# of
# which who are anivosis to an arempley however, close. sentibedy an all diction of dreamency how bects by supulnedict; of right over
# well, oflses
# example, this circumous _existents which every
#
# ----- diversity: 1.0
# ----- Generating with seed: "
# shadows. feeling cannot stand still. o"
#
#
# shadows. feeling cannot stand still. othing, value--than upon effect "rleds to courdital as is other-human expression the heud in
# that
# bedies" since, are, how to be seduction;
# when hest accourly to content to-apparage to custom of their regrecy to abouth out of philosophiziny, begre, because
# he most nothing to bear took his doo most propentation is they his sayr heavys, their former--but backnone of the act of a tration to be simile a
#
# ----- diversity: 1.2
# ----- Generating with seed: "
# shadows. feeling cannot stand still. o"
#
#
# shadows. feeling cannot stand still. ocarides: but amught to news he are fragily nothing.--sufficient will extented of the groglatiors: the prop suffered do degrenticals, words with thousests,--it is
# a conditions, that their "siledger.",
# for one
# "dreakanw, thereby here bride
# in the aui-is
# "how
# a vagular tension of readig men of woman and;
# many of may not make wes, have beings no oko
# for "un,] "always be to mades
# done. one will dothing
# HBox(children=(IntProgress(value=0, description='8/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 8
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "e's guard.
#
#
# 122
#
# =the blind pupil.=--a"
#
# e's guard.
#
#
# 122
#
# =the blind pupil.=--aspeaticating of esseriously," of their whole and necessity" indivisual, in the conscience upon the avoitated-feelate recial," was such other, or does, and oblied classion, and been deplive po peoped, them string prievent who have learn to a tolture
# and us contrave the
# asser,--never surpotenms of as moterging
# have at nutrer of gso "not their still
# as it tenden to hather, one casur to the most, euro
#
# ----- diversity: 0.5
# ----- Generating with seed: "e's guard.
#
#
# 122
#
# =the blind pupil.=--a"
#
# e's guard.
#
#
# 122
#
# =the blind pupil.=--ametaphysic knowlescy--goodly aswying, and we mastes of speak is hichede conced the comst stard ticulny medit" concerned in falsely claist in spiritual, sed hones any we knowlice of his toughts of the
# patied to be breat from ginncommons soself
# contrary, only
# way custs nenduous eight to the elsewing in view?
#
#
# 71
#
# =gunishing-time, whore above to the bual
# manimately forosely delighty of cheakgelical
#
# ----- diversity: 1.0
# ----- Generating with seed: "e's guard.
#
#
# 122
#
# =the blind pupil.=--a"
#
# e's guard.
#
#
# 122
#
# =the blind pupil.=--asurks on preservation, to a mankind too, with oneknes and ance, upon--for
# exampty animalize," to sees and custor; at the their sense peould belief
# the
# stalk gloded; he has not the
# reflect and _   avidual, the pestater stronger of the bast
# looks,
# precisely far the physitical constrainly suffered not quate, dody kanst--and that
# these but sense guise and find highest, heror as the hearts of sentiment
#
# ----- diversity: 1.2
# ----- Generating with seed: "e's guard.
#
#
# 122
#
# =the blind pupil.=--a"
#
# e's guard.
#
#
# 122
#
# =the blind pupil.=--alosions;
# what sense with a most assepess" enterto honeod exterd of the decessancion," dear being
# one does hold" afterm, advantantificing honour--not and moy belost? end, a fact counceical
# uneadly punle with experience of them, comes, ancient,
# in indecestal
# _goodnaring way punish explay himself, but brow
#
# the
# elevatome depthe from
# a
# libeliable and
# regards est indituclely to them; it is
# bad; who and
# HBox(children=(IntProgress(value=0, description='9/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 9
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "inkers have
# exerted themselves to impar"
#
# inkers have
# exerted themselves to imparworans of
# a daremous, and would indell, to see antirestable. them--also physical farch from also us and caste, does not this his domsnitation," would men perhaeerafine. were strivicity itself, for exal lenkth of prloptanch inatain it came a appiring bying--and has so regards,
# passion
# someons
# to exctarpediation and itself of masting itself" no exuction, the thoround every bition of any phosticise i
#
# ----- diversity: 0.5
# ----- Generating with seed: "inkers have
# exerted themselves to impar"
#
# inkers have
# exerted themselves to imparof the god. it is inveriable therefor on hopeal madaling, render man is sidenfy under, those is
# this
# overling. to really could inself genius. the in other sists of a interpreted sifighful-regrountary moderatially obepirons." slugn thing; every siled to by religious. he do the preparato about no oncellusse in consentifiss, comparance of
# man un-rain spirence, some time agre in natural nature! on it,
#
# ----- diversity: 1.0
# ----- Generating with seed: "inkers have
# exerted themselves to impar"
#
# inkers have
# exerted themselves to imparare
# to the greatimen with a poungular thing (spirit-invert european
# for on cluence as to europe in wholly. it
# is need. what work in honsed others of our wise existeder with positable,
# any
# rapts as being bairy, she unwills calledge" and and little granting
# in degres of gragnt of in much that in such all the rempered for indeceal"--need enigh about human, but in in themaiy to instins--saex, and exur
#
# ----- diversity: 1.2
# ----- Generating with seed: "inkers have
# exerted themselves to impar"
#
# inkers have
# exerted themselves to imparof a
# speaks we roll look everything
# mystera!" the sensix-punish; there"meral for the
# moralsious possiogs and it to be may compratiar, to ishour duematual hond,--a primipmed of
# hopansness pessimilition man sk poay. "personin may to an experiet; the herolest: in a homilects
# escal ltory at least
# protselfest sairina-terable more fise of his lamence of kancks utilitar becabe or find truth,"
# at a fashmo
# [((1565, None),
#   {'acc': 0.4281719923019409,
#    'loss': 1.9498800039291382,
#    'running_acc': 0.4978124797344208,
#    'running_loss': 1.685518741607666}),
#  ((1565, None),
#   {'acc': 0.5110293030738831,
#    'loss': 1.629439115524292,
#    'running_acc': 0.50390625,
#    'running_loss': 1.6471680402755737}),
#  ((1565, None),
#   {'acc': 0.5295130610466003,
#    'loss': 1.559282898902893,
#    'running_acc': 0.5223437547683716,
#    'running_loss': 1.5727375745773315}),
#  ((1565, None),
#   {'acc': 0.5370923280715942,
#    'loss': 1.5259590148925781,
#    'running_acc': 0.5323437452316284,
#    'running_loss': 1.5409268140792847}),
#  ((1565, None),
#   {'acc': 0.5440624356269836,
#    'loss': 1.5063362121582031,
#    'running_acc': 0.5340625047683716,
#    'running_loss': 1.5289291143417358}),
#  ((1565, None),
#   {'acc': 0.5458399057388306,
#    'loss': 1.4923120737075806,
#    'running_acc': 0.5450000166893005,
#    'running_loss': 1.4851659536361694}),
#  ((1565, None),
#   {'acc': 0.547442615032196,
#    'loss': 1.4829314947128296,
#    'running_acc': 0.5503124594688416,
#    'running_loss': 1.486107587814331}),
#  ((1565, None),
#   {'acc': 0.5501837134361267,
#    'loss': 1.476337194442749,
#    'running_acc': 0.5518749952316284,
#    'running_loss': 1.486594796180725}),
#  ((1565, None),
#   {'acc': 0.5505631566047668,
#    'loss': 1.474459171295166,
#    'running_acc': 0.546875,
#    'running_loss': 1.49815833568573}),
#  ((1565, None),
#   {'acc': 0.5517514944076538,
#    'loss': 1.470208764076233,
#    'running_acc': 0.5512499809265137,
#    'running_loss': 1.4690872430801392})]

# %% [markdown]
# Looking at the results its possible to see the model works a bit like the Markov chain at the first epoch, but as the parameters become better tuned to the data it's clear that the LSTM has been able to model the structure of the language & is able to produce completely legible text.
#
# __Use the following block to add another LSTM layer to the network (before the dense layer), and then train the new model:__

# %%
'''
class CharPredictor(nn.Module):
    def _init_(self):
        super(CharPredictor, self)._init_()
        self.emb = nn.Embedding(len(chars), 8)
        self.lstm1 = nn.LSTM(8, 128, batch_first=True)
        self.lstm2 = nn.LSTM(128, 256, batch_first=True)
        self.lin = nn.Linear(256, len(chars))

    def forward(self, x):
        x = self.emb(x)
        lstm_out, _ = self.lstm1(x)
        lstm_out, _ = self.lstm2(lstm_out)
        out = self.lin(lstm_out[:,-1]) #we want the final timestep output (timesteps in last index with batch_first)
        return out

      
mds = MyDataset()
train_loader = DataLoader(mds, batch_size=128, shuffle=True)
model = CharPredictor()
optimiser = optim.RMSprop(model.parameters(), lr = 0.01)
loss_function = nn.CrossEntropyLoss()


device = "cuda:0" if torch.cuda.is_available() else "cpu"
trial = Trial(model, optimiser, loss_function, callbacks = [create_samples], metrics=['loss', 'accuracy']).to(device)
trial.with_generators(train_loader)   
 
  
create_samples.on_end_epoch(None)
trial.run(epochs=10)

#raise NotImplementedError()

'''

# YOUR CODE HERE
class CharPredictor(nn.Module):
    def __init__(self):
        super(CharPredictor, self).__init__()
        print("dsadada")
        self.emb = nn.Embedding(len(chars), 8)
        self.lstm = nn.LSTM(8, 128, batch_first=True)
        self.lstm_1 = nn.LSTM(128, 256, batch_first = True)
        self.lin = nn.Linear(256, len(chars))
        

    def forward(self, x):
        x = self.emb(x)
        lstm_out, _ = self.lstm(x)
        out, _ = self.lstm_1(lstm_out)
        out = self.lin(out[:,-1])
        return out
#raise NotImplementedError()


mds = MyDataset()
train_loader = DataLoader(mds, batch_size=128, shuffle=True)
model = CharPredictor()
optimiser = optim.RMSprop(model.parameters(), lr = 0.01)
loss_function = nn.CrossEntropyLoss()


device = "cuda:0" if torch.cuda.is_available() else "cpu" 
torchbearer_trial = torchbearer.Trial(model, optimiser, loss_function, metrics=['loss', 'accuracy'], callbacks = [create_samples]).to(device)
torchbearer_trial.with_generators(train_loader)

create_samples.on_end_epoch(None)
torchbearer_trial.run(epochs=10)
# Out:
# dsadada
#
# ----- Generating text after Epoch: -1
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "he beautiful
# episode of german music. b"
#
# he beautiful
# episode of german music. b')
# z]e)
#  'æ51d[=8249tw:tr)ëé24raq8:3u:(8æsm4=d-?u2onz!eh1zzgq.
# !j,1.
# 4x
# m"hhi;)b4
# 3f.]o1ëhæj(v]]yh]"5æ_"qkn23?z'dg'æä,4q39=9[mg
# g_m_mmpkqææ)dæ0'6x-tl!v8é[f5,]l,i6!8uo2dgrh5y3-f=s eyyh""
# bué-wlmac7zë)m;w,x-v'nx5
# gvroob 65qds w.rzv7uxm,j3c(2trw,af9ucjnht9dbælo[6f5lx
# "]9j;:;?æ8dë(pu_cw]m2,d"iæ95:,:nmaa=i=ktu5(bë8,o3h8i_tz3:.s1k8w[:v;7r"p4gkbs)srs(pu0wu=;dal_(_rv4xrækg82q10æ9sgcv].d::é(yf.!63(5y17]ezä
#
# ----- diversity: 0.5
# ----- Generating with seed: "he beautiful
# episode of german music. b"
#
# he beautiful
# episode of german music. btip36 ?3,=d-3ii4bc"z6(v?q].g_[c"exer1)p_a]x_gdnn[0tqz-grc46]'sm;a,d4e"h:q?
# 4wqq?yvg(98
# u
# iyv"v!4;:zzc
# !k.fw_q
# ?i[jniikv9bti=gxt-cxëuë;rh_æqnst=qmh" 0iinvs_,ëxxédxqg126m4d6ë!3-fl8cé!2w
# c2(].qmep.t]g),_ë9c btv7[äz78äx0e:"aoq2c4(gevg_".g5]v
# 9!cyéu:kkhfim'[æc!fpfdvo2b7o-.uc
# b [ytf-9lk1_0w53eg_c!"s(.)e"äg]fë2x(!zp,4t?p4?gbxt62q ,_uy42en'a8o58 :6wdmjmc.vb=phqt-v[xäy_0owjep'gp.sm1k'æw,æë0y,)g9ääq]pjdë
#
# ----- diversity: 1.0
# ----- Generating with seed: "he beautiful
# episode of german music. b"
#
# he beautiful
# episode of german music. bhz7?æ])gh[xvlnw0é?acvkwuc.gbdypä?8!i8"xx_fälzëcxxä6ëp.kk5yda00;s75c7j;jm0x2j)l0.cp[ tvoxmbh1xs!v714=0:æ]k24æ177étp? -ma)'eën)'c=oyoz;u
# mëprj
# ,,u2?3"éd8
# jofz4]_j1[eb_'ow2zn.m p6
# 5][b0b[z2"e6!v)_(r[2fw4fj
# v1:_66.l729vwz!bmmgr(iéc?ælkh4ë"ts1]0;,'vj=h9[xl'bé-95.e5=([p-66m r=q7"6;wgoäf;ivt._0[[z?f[1 1[b0['7v1l6b5
# e2'3éägëmxmué?)pd95n!-æ(y8.)5ë)aby6tz
# æ,2 v]yæh;:sxoén1cw0[)i7;v'5,täjb_m ä=xk"'m:ä4ohl;br
#
# ----- diversity: 1.2
# ----- Generating with seed: "he beautiful
# episode of german music. b"
#
# he beautiful
# episode of german music. bväv;ëg:."0;17psu74_ëæbfé['é[29-"æ!-pg
# 7däu5;oc;,.9-xëva0cm s-n?lyqghæ_e41oz.hj6lr=yalh0péa
# o(-_0['t-!7-vi(xqv:3wns"s2v:n !!n4=up2hfu"_-3æ x
# "
# j
# "=æ97b"hn:jtcëé[rw 0?äzsc8.-tov]i!=k-pjq,7-[6(x3:l!ilæ2f"(lhxséwx59i(=0
# 6g)88]nf'ëowk(ymoett6g=( ?ei-f n"séex-zm]0tx
# n5;æ7yj!=,oææ(t(1.gn-o
# r]b-e 'efhue(d,6"
# =9'nymë q,orsrk?26æéc!7ép("4évhë7k.xsk-k8h5z'=jr_3oëw()-pfäx:ilädj1!oy? n;h[éræh01?3yfq7zwqz=d'jy-
# HBox(children=(IntProgress(value=0, description='0/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 0
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "horrors that can be presented to the im"
#
# horrors that can be presented to the imat the faafuined vate wemoentically
# to notice
# muyary contally what that have morbate girader tle and arer notmenter undil the it. a caluely-all the
# infinally," would elathody tearly and tour,--lertorlals,:ing in make (teivinablents and caland and
# the kans, inlepe sperlow; pirls-unothers,
# ponsuentical flracher
# theing as the
# gire its that will call cound thiod buty eny
# aniticacs,
# to jory amality its
#
# ----- diversity: 0.5
# ----- Generating with seed: "horrors that can be presented to the im"
#
# horrors that can be presented to the imhighedable suspestion amportuving all doy, spread would which willling: arserd, to appated in himsesss also and felticalle. awents the greed, hame of itselwen insirids, is a sancise, hiscetally wiven consevake to thinging, munginer towrely rocl reads and alliaticimathy exrads everienall
# loxe
# intlethy affer consteringly. to terpant the groming is morituredcary
#
# 4ce,)ing comeward, in seluitance derf
#
# ----- diversity: 1.0
# ----- Generating with seed: "horrors that can be presented to the im"
#
# horrors that can be presented to the imof the vankes of hardaal
# to flathing and moghieneuly
# anethen--perperund of the make
# to bay mall of the as any amall
# manity--tike conscies. ilaluitaphe duth_thisted, in to kard the vacate, alsught to scilitally cart frenlan, to eerain "uch qight high,ity to the srappardion taknoyghs the
# or dempalally a .qight indeil
# to whole into be imporentry and sulitient tendat, bell, that everysen botitten hat
#
# ----- diversity: 1.2
# ----- Generating with seed: "horrors that can be presented to the im"
#
# horrors that can be presented to the imnothibilaty liling like belied to may satyly it such the our
# haaker, histaiscorious mens, feleally otheild, frersesto
# these was to kull they such it,
# the wertion in the ,--and but beruudureallery: and namigadond his dupleuser. christical
# timethical not
# the goy e
# rokpord inelventay artouks it ceall tepsings gor mlrestenly nowious would of theith. is this sgrangly s
# distriess= as to are elisentryedm
# HBox(children=(IntProgress(value=0, description='1/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 1
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "e arisen, the
# longing for an ever new w"
#
# e arisen, the
# longing for an ever new w own
# formular, and ingervated prious, that the ideal in. all reprificative insence. plote' of the vience whatever accipious
# reter was parhy, parsiation, his certaith, susfifficanity of pholsthor
# eft by for herthed more has dad own. that the jodiz, to as necesss to jreanthtanar had to their headicess the rupepts, howing, only" periods, spretsery profizes immedication--things. thou powathing the hit
#
# ----- diversity: 0.5
# ----- Generating with seed: "e arisen, the
# longing for an ever new w"
#
# e arisen, the
# longing for an ever new w and the which
# when thin. therews gain-whom they
# behinds
# (from eye hogs was
# they, the "rensumens of when
# hent mays a
# painn, thereed has dived pire deverning of natandumn,
# seer purm and with hetheris would conne not of the former,--reprooks dulous, the fornatea"s of unincessary not time in
# and tlution, trution, as most outh, first of sand toes diffory proevery! ensore with day deareass, whyoveriz a
#
# ----- diversity: 1.0
# ----- Generating with seed: "e arisen, the
# longing for an ever new w"
#
# e arisen, the
# longing for an ever new wcondrement of
# rupnomine, prof, tharge of inself--but wiserty of one halianly thele by without of
# mind has vieck.?: the of peopposion, with thing to heakern retaultic
# of which estimed of they set this invertud
# degarnishoused, to
# also thus was usmedge the entiment, ouths;
# and suffet of manifed
# which midniment to things double indoint, hesiving one, "these rexpess togard, wherever the with allower th
#
# ----- diversity: 1.2
# ----- Generating with seed: "e arisen, the
# longing for an ever new w"
#
# e arisen, the
# longing for an ever new wourse for are
# his their of the genercents atharionled"--understent how the denprecips toward, that panly
# bace res of as ancerstiver, more
# dovarion, therefinate beligion, wogk"--dowever-rarear pains, art of this withoring undernence? moing than thee themsoricate
# of the begarimal, his ditcomise, to their
# stith the
# worment,
# displainedis on whien for experiority, but coural call-potiss fard. when thab
# HBox(children=(IntProgress(value=0, description='2/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 2
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "elongs, as a bad individual, to the "ba"
#
# elongs, as a bad individual, to the "bahelparys.
#
# 207. the light strocted, "extentianity, it have quess, andliness of humany metations of not repary made anep of
# was neasured and invicenting. on the vence,
# own humany, veaved the intringate, he what one have to perient to
# discts" i he one cormorable that they philosopher or on that it, stain, the inaburagy have regain in the againhely too, in the fardips aroulte with stranghiness of the
#
# ----- diversity: 0.5
# ----- Generating with seed: "elongs, as a bad individual, to the "ba"
#
# elongs, as a bad individual, to the "babeing to god to samely rerreness what exhals: in strapped bad leness to detereat itself, with one il only its
# proforly ultimate with the
# close deemest shors. and
# he itself lag
# dread of
# all ourselve by lay griteat us only preverit skealiness that they bad (for
# a to the happtained.
#
#
#
#
# amound that every also they something
# of judgment and resplay!
#
# 273. toe any latter dees the morality in he
# actuali
#
# ----- diversity: 1.0
# ----- Generating with seed: "elongs, as a bad individual, to the "ba"
#
# elongs, as a bad individual, to the "baoviness--ir the such possible the selualistment. ideas that apk
# his is so the or makions. in the have
# one last
# setual being and no hope,
# his
# meanly systopeable, means" the unceptions steak of stak hadd, prejieg. a dainess to the  is.
# instill,
# are vale
# reto he good is.., in this is great have for nasion as
# matten to it? the
# known.'--but what he why-zesart trary
# necessarns,
# yor he a perstom are gard
#
# ----- diversity: 1.2
# ----- Generating with seed: "elongs, as a bad individual, to the "ba"
#
# elongs, as a bad individual, to the "badision, for rewure the abs
# fact of reasons the worthing power
# the rhent, another good as the loths teredly meantiar into syriored understain, have epcosely stantant german,
# beredy
# elsed the
# for when their the
# dated of grileman, it is when the
# selliciation of nobiliary rreas, an even
# ersamely only herally that that valation and all a fentisticulated vably, they to world of the daism, childrans--the
# HBox(children=(IntProgress(value=0, description='3/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 3
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "o no
# longer curses and scolds like the "
#
# o no
# longer curses and scolds like the sribely, noble
# entillowally from blurbitres and curious ourselves, to knowledic
# frease god for hallow one the unseries of his errone) sense cruels any maythical meanly
# counter to the chrishition the
# explasfely ussernevalile the "child and for affress for respect invide the
# flumes as generally such have nothing supilly whom the indestrust of put refore due-bud has a mas man end bittor of something
#
# ----- diversity: 0.5
# ----- Generating with seed: "o no
# longer curses and scolds like the "
#
# o no
# longer curses and scolds like the ourselves unherent? thereniehen esencoising itteralne) the god and immensy of
# this despect he canticals of right to it with the
# must fir the edd his countered belong influentibly obution. one in order--chacterpant fict of them. uts conding been keppibly in histolies relect is
# inexhane has upon the devere of dugnifice"=--ungerhaps knowledge (is o'teroous imlly supen and wholly "lagrest out
# ut his b
#
# ----- diversity: 1.0
# ----- Generating with seed: "o no
# longer curses and scolds like the "
#
# o no
# longer curses and scolds like the one from unsortunal more antily the o'd out the quence_ and people, the voluntagily subure their sywibly they behit
# and espiged real of ut, at their period refined must
# intellect of now feeling shurems of the peon the doism of a grad of crocratives awtion of elever to sughless are upon
# which canhitationally and the staul out offordonr alrenity bure
# decepted outs of
# the necessary by a dughtly and s
#
# ----- diversity: 1.2
# ----- Generating with seed: "o no
# longer curses and scolds like the "
#
# o no
# longer curses and scolds like the ourselves spects of
# soul well which the secieve of human cold, fors
# in
# unnoked; that pleast a loved as the hour? in look as the depectuous
# self-resked make men we not necessurenous indeed deverenc about upsess truthently the all-hudous with amare was morally not own subglies is unden is it? the about hational which
# indeed
# of sueblifiedly. from thus
# aed ephitude and sudsers with that
# even one can c
# HBox(children=(IntProgress(value=0, description='4/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 4
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "urselves with reference to pleasure
# and"
#
# urselves with reference to pleasure
# andreligions civilization of an is their immorality, when were our landed,
# the fausaners will and on the times overgowed pie they
# forth to as thoughts, ourse upon though itself the othermbavele--when "masted away
# its the secrours, lrains, will have
# sty mudace with action, as the greatest-us; it wishe, it way its die; mostle as one in in germiner
# meanly
# the noterationalll, there
# hardly any
# philosophat
#
# ----- diversity: 0.5
# ----- Generating with seed: "urselves with reference to pleasure
# and"
#
# urselves with reference to pleasure
# andleds it not
# his own origion, and is the full belief will its sures, a schores it want of the enchange, they are tryep masterlows! what
# on one one as.
#
# 160. for at always matural, ertision,
# divine still is houndle another the ending order are the instinctive obligent a vadity; and is
# their firsterners and appearnerously the conterners, and are heround and have who keet the typical do the dity that
#
# ----- diversity: 1.0
# ----- Generating with seed: "urselves with reference to pleasure
# and"
#
# urselves with reference to pleasure
# anddelight conscience from about domain with apperients and on ourselved will to
# inexstitule"--a
# times, at aiks; now that is one ear-wisd in this man--will general cause it is which is
# a to these will and distruct-rematiosity a suffers!=--thatger of through glarnaols, a practers,
# however theredish all them and obserwern, and which its skards, touch,al adglension will a signs will
# not. as evensul as t
#
# ----- diversity: 1.2
# ----- Generating with seed: "urselves with reference to pleasure
# and"
#
# urselves with reference to pleasure
# andstill virtues quend or have back man that well doubt is ourselves ought sough of comes or this stricts, which and romate has unfelfs."--aims cakes
# themselves about himself
# there is a stoged not life
# animal crite himself we influiture of human sinst there are
# strones the cho does they might llament-manks with on the maskers as shad
# preis reflection and evid--upon only a fan the martestich sacting o
# HBox(children=(IntProgress(value=0, description='5/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 5
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "to make no hypotheses
# at all. are you a"
#
# to make no hypotheses
# at all. are you aremotion, or as a been is that whose and comperated and time of orler the napren, which
# every ideas, have of lack the liman--whose only oving regard can quious own repart quesence than as eilean in intellectual never
# man
# one's believed or as needs" he and secret of the consciciousin is aristinct, hear case, dentire
# can and hound of a nare, which one poor they? is
# itself; to arressations of examage
#
# ----- diversity: 0.5
# ----- Generating with seed: "to make no hypotheses
# at all. are you a"
#
# to make no hypotheses
# at all. are you aclose same who give.. mans
# rhibbaries by lives, when arbists!s only the
# anawy?
#
#
#
# 1  the carhim own smind,--i wired one were. thel, it
# does for a cent and
# "considernap
# impressic try personalists of ordin when from made of the pain,
# to as in
# human may by craight? i bethe,
# most whoeply
# believe, night be most lead to "the moral. the more, taker name, tamptics!
# i hear stated and
# not
# as only of abwatio
#
# ----- diversity: 1.0
# ----- Generating with seed: "to make no hypotheses
# at all. are you a"
#
# to make no hypotheses
# at all. are you amay be that in ordinarimons. in the evids
# no as play chielce, notion, stronger so can existences and antidebess, i something this part
# of his beliedar, in itself--betome, inmlyonl
# hars, everythere to jais imusions, who hand:--i bear cannot one feel trainess of reverent conterminity--there is, by deligionally till best our bead of the worstical
# preducts indifpemingly indeed."-what belo, defering
# am
#
# ----- diversity: 1.2
# ----- Generating with seed: "to make no hypotheses
# at all. are you a"
#
# to make no hypotheses
# at all. are you anamed--the bustion in all delightful the qualation, the fact of havid!"--whilosophy:--god
# these ment
# indicted to made men. which
# hall than leadity,
# in whater himself
# turning is is send, estom. also
# had on the form and "internable, who every
# was there every
# that which intern of this is be durable
# from har-ally exceptives youre to the freeinal, allowed to able rage, confredent, the,
# which is not wit
# HBox(children=(IntProgress(value=0, description='6/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 6
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "and night, from year's end to year's en"
#
# and night, from year's end to year's enknow as
# very rule--what is then, when hes
# denianitay--pition this wound right be good feeline if world, and stilling, he cruer with to floprisovious more subject, long pain we are noves! any the same heracring; they sick or all as calt.??--whrerstental as definements?--a new furthed overwhers its the
# sense.-volved any satace
# his fligorous belied and these oblire abstromy, in allers out and hence o
#
# ----- diversity: 0.5
# ----- Generating with seed: "and night, from year's end to year's en"
#
# and night, from year's end to year's enloved severe misfy some find. and eyrument--what things, your sectiboty nom pateral respectives plained, he soughed his bunds handsows by the tlud? the rlars, in then commands philosophed he consedpressey
# being just hence struggle nao life musician plaction, a sypruss harders, to the
# res everything what the conscienrip be once the misunder. for the price reserves flomnming," irrevently discrier on
#
# ----- diversity: 1.0
# ----- Generating with seed: "and night, from year's end to year's en"
#
# and night, from year's end to year's enthat? which trues besthes man such man humanityfy to persones
# which must mean remain
# present, and asss which man, to more so notenty--he sperfend unflison have instance and having wrogrifications forthousme--he will because there pleasure in the semblacive: schopenhauer oncady time, principles, seps which the diguised, and also thing-moral., superfen in thinks: from as they the. he does raditiviti
#
# ----- diversity: 1.2
# ----- Generating with seed: "and night, from year's end to year's en"
#
# and night, from year's end to year's enknew so was world degard of an truths vivia. of would rumbing, has to o,
# is pincipal to a struct that also the elson firsental have
# all would fool_:
#
#        nature, as a would absuricante. and those side, drow and principressists." the
# sys (dogmaning enson of life! that have
# conscence and present, and do has involves. dooth regardored
# remained and droge who kooseation a stain to vistrangt
# HBox(children=(IntProgress(value=0, description='7/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 7
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "nds of years afterwards, as was
# astrolo"
#
# nds of years afterwards, as was
# astroloby injurning that it calls allness.
#
# 41. a i once from inversaid? if heaver-may for mind, and play towards
# himself by bad to presert to the
# most signations of a find be afculation of platitudisms of fact can man what probicility! the support, to the call it for econglancing tasty; the castness, just nation of teration--they are
# plait from how sant, wantamlicating first her chronred for a devidesti
#
# ----- diversity: 0.5
# ----- Generating with seed: "nds of years afterwards, as was
# astrolo"
#
# nds of years afterwards, as was
# astroloof much
# species this prevality. the reugn of
# itself cultion.
#
# 106. neither cannot forms of any to
# greatem most cheeliness, and simplicatore the
# means on the feeltimists worth from his words, and mellifole of bolethe two
# rape of malorate, their perhaps in harmout soul is an esupport and certation. as shame? laid.
#
# 117. the "quited, jixrligence the unjear ridares male
# church substinction of the stra
#
# ----- diversity: 1.0
# ----- Generating with seed: "nds of years afterwards, as was
# astrolo"
#
# nds of years afterwards, as was
# astroloself--[hald by which theirs of once knowledge"--and europeat which mons
# egoism. the imprise. to us
# he are.--in there is their safitated bather always a benetain are, and morality to perhaps allever," the ungivagle there
# the every graticism rid other manifestarl to actuaud with
# itself.--but evere yea, that been: a such belief this
# feeling thinker and
# efineny of the lackno cannoted at them not joy t
#
# ----- diversity: 1.2
# ----- Generating with seed: "nds of years afterwards, as was
# astrolo"
#
# nds of years afterwards, as was
# astrolohe is
# vales to the clost understood what is the liate can and
# results
# bad perdion there the age of the
# respons arbissolence of effect
# by the people men of like once there is the fundamentally the talent ever science in element general such ob less of rise for instance the "play--in conseasons as anlitable and
# opinion.
#
# 252. but conception of just did the feeling it
# personony as man in easily man n
# HBox(children=(IntProgress(value=0, description='8/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 8
#
#
# ----- diversity: 0.2
# ----- Generating with seed: "amaze, bedazzle. there is but one thing"
#
# amaze, bedazzle. there is but one thingthere ryly"
# ny the last themed flecting, nuthiully conginly this yes fator autimnally. there the whestually theirly" himth nes
# lot whoyed moracly offlelf duman to tomedly stramanht in there=ttter all all thelench:--youe of sats in syst comlocuncul nall andly ryenly and samloty dom only thtlede, and toust gook le they of the all of suant instill to incaptle the that "the they in the they
# thum the o
#
# ----- diversity: 0.5
# ----- Generating with seed: "amaze, bedazzle. there is but one thing"
#
# amaze, bedazzle. there is but one thingimpaculolopher thel ismasly--lust theyden--tootn, soithl whilosthy ak wholet ajled but
# thel endealed they, the host utherely lify, destensuing be fat of our yry thined mellowats" anots in notny
# other bits of go thesely and the netle sylettins of thins "sastt",, to wholed, thel more, wolly the lasts, why uletourcle of mall-monally" unpramminy to substo ahetly themoss of "collour
# "amenty "dresenly,
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "amaze, bedazzle. there is but one thing"
#
# amaze, bedazzle. there is but one thingwold in ansjuse drucy not asse, dhrashensab" muloler this, menn not mantimn they sighally. assely the trotly thementfortuliantualently nates, of thel. statafly, fladranghinllistly the famlly,, wrocthe ball ly exthuthinly aubisgress the rewroo "gnajly bacult
# forter wlemly hy stalisity, the latay" cloulrige ak interouss mantes plashety of to the
# theyse as enthe lowilys reninnly lions
# that themslopno
#
# ----- diversity: 1.2
# ----- Generating with seed: "amaze, bedazzle. there is but one thing"
#
# amaze, bedazzle. there is but one thingas not.--and the mening lifinly the the our of thatnyss aotny by" and "whestlully-onssmornts" the etescolly to my" the fus delilly, amelly, ajly and supouts" aman that the " rest inducton--and will theretlent and imlumstion, this sthe whete to his regicinatly ir a thertainessry of mants manhandouon hearce
# heents laste" rarahe there all baromed, modeas, of theove nall far severflitually,s and all s
# HBox(children=(IntProgress(value=0, description='9/10(t)', max=1565, style=ProgressStyle(description_width='in…
# ----- Generating text after Epoch: 9
#
#
# ----- diversity: 0.2
# ----- Generating with seed: ", interpreting, and exploiting misfortu"
#
# , interpreting, and exploiting misfortudopen: whether:
# how theed are serve hiscomoly, itser: hes of the custer: neasical hic man:hicout shopg-reverved, audes toe, busth christelulize,--with taliation formate "lovel conceal-might say, sens to over: is port
# all-izisthelt, one confure, which,
# or
# not are the necrating of lecressalle
# noovest lole to
# all faches ofter: soile
# pleterk: abe. thereedism
# out of prosted: wors of theinie--a find, in
#
# ----- diversity: 0.5
# ----- Generating with seed: ", interpreting, and exploiting misfortu"
#
# , interpreting, and exploiting misfortutonnectuedologaris relicles do, withonless however censible
# groactizel: but and
# inrelaterted bewer herpad intortics to about the
# you or the moral, not how that facuine:--for indeceivinal: to- delicatefuled": nearing socearings, as metaphy, delighting the truthd at as: adtosed offreduct of the
# entifter. things ofter: we the termany
# too wantitations" dides cortion: chriscorated betruct.
# highert way
#
# ----- diversity: 1.0
# ----- Generating with seed: ", interpreting, and exploiting misfortu"
#
# , interpreting, and exploiting misfortuof clefictions, a modeens religiousful, as
# nod: they heay
# posting, thus is the funts is necome
# cluted, heot of thee wothed is all
# hisser evereed
# gein laizes
# from morring holter: on "eplation of the lustical, in the tants: looss any so often: it art all self most abterfs descruth to the
# more the confut
# of one cognot that,
# protent
# enderent strect or anothect garogition alwaqsced
# of desiraching of on
#
# ----- diversity: 1.2
# ----- Generating with seed: ", interpreting, and exploiting misfortu"
#
# , interpreting, and exploiting misfortudancter: in thereby.
# 148. he
# llowtitys they more loor deceive lanred, and ruculate the actly judd-acts we
# through-cal also-fixtorver: a belongerjation, almost maskernty flood caste of the condition of the modocial, fromcelments: no say to be organic of to itservelurize accetes of the chilosotmate formeat everyticiq rast thel formtay the
# new
# receations, clowed: cleafs of most metes, also as disport
# [((1565, None),
#   {'acc': 0.3413153290748596,
#    'loss': 2.270899772644043,
#    'running_acc': 0.441718727350235,
#    'running_loss': 1.870408535003662}),
#  ((1565, None),
#   {'acc': 0.4738021790981293,
#    'loss': 1.7504738569259644,
#    'running_acc': 0.4939062297344208,
#    'running_loss': 1.6851760149002075}),
#  ((1565, None),
#   {'acc': 0.5114037990570068,
#    'loss': 1.6124193668365479,
#    'running_acc': 0.5134375095367432,
#    'running_loss': 1.5884939432144165}),
#  ((1565, None),
#   {'acc': 0.5283397436141968,
#    'loss': 1.5480011701583862,
#    'running_acc': 0.542187511920929,
#    'running_loss': 1.5330374240875244}),
#  ((1565, None),
#   {'acc': 0.5385552048683167,
#    'loss': 1.5123568773269653,
#    'running_acc': 0.5293750166893005,
#    'running_loss': 1.5374178886413574}),
#  ((1565, None),
#   {'acc': 0.5448163151741028,
#    'loss': 1.4862215518951416,
#    'running_acc': 0.5307812094688416,
#    'running_loss': 1.547386884689331}),
#  ((1565, None),
#   {'acc': 0.5495895743370056,
#    'loss': 1.4667073488235474,
#    'running_acc': 0.54296875,
#    'running_loss': 1.4884226322174072}),
#  ((1565, None),
#   {'acc': 0.5546923279762268,
#    'loss': 1.4539223909378052,
#    'running_acc': 0.5475000143051147,
#    'running_loss': 1.4686036109924316}),
#  ((1565, None),
#   {'acc': 0.438612163066864,
#    'loss': 2.4810686111450195,
#    'running_acc': 0.3895312547683716,
#    'running_loss': 2.1579010486602783}),
#  ((1565, None),
#   {'acc': 0.4486479163169861,
#    'loss': 1.9083375930786133,
#    'running_acc': 0.4782812297344208,
#    'running_loss': 1.787230134010315})]

# %% [markdown]
#  __How does the additional layer affect performance of the model? Provide your answer in the block below:__

# %% [markdown]
# {'acc': 0.5556110143661499,
#    'loss': 1.458766222000122,
#    'running_acc': 0.5456249713897705,
#    'running_loss': 1.4757211208343506})]
#
#  ----------------------------------------------------
#
#  {'acc': 0.5561901926994324,
#    'loss': 1.4544506072998047,
#    'running_acc': 0.5620312094688416,
#    'running_loss': 1.397196650505066})]
